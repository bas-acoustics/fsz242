# %% [markdown]
# # Colour maps
#
# Here are the colour maps used in the paper.

# %%
using Colors
using ColorSchemes
using Images
using Statistics
#using Pkg
#Pkg.add(PackageSpec(url="https://github.com/RobBlackwell/Parula.jl.git"))
#Pkg.add(PackageSpec(url="https://github.com/EchoJulia/EchogramColorSchemes.jl.git"))
using Parula
using EchogramColorSchemes

# %%
ColorSchemes.viridis
# Out:
# ColorScheme(ColorTypes.RGB{Float64}[RGB{Float64}(0.267004,0.004874,0.329415), RGB{Float64}(0.26851,0.009605,0.335427), RGB{Float64}(0.269944,0.014625,0.341379), RGB{Float64}(0.271305,0.019942,0.347269), RGB{Float64}(0.272594,0.025563,0.353093), RGB{Float64}(0.273809,0.031497,0.358853), RGB{Float64}(0.274952,0.037752,0.364543), RGB{Float64}(0.276022,0.044167,0.370164), RGB{Float64}(0.277018,0.050344,0.375715), RGB{Float64}(0.277941,0.056324,0.381191)  …  RGB{Float64}(0.906311,0.894855,0.098125), RGB{Float64}(0.916242,0.896091,0.100717), RGB{Float64}(0.926106,0.89733,0.104071), RGB{Float64}(0.935904,0.89857,0.108131), RGB{Float64}(0.945636,0.899815,0.112838), RGB{Float64}(0.9553,0.901065,0.118128), RGB{Float64}(0.964894,0.902323,0.123941), RGB{Float64}(0.974417,0.90359,0.130215), RGB{Float64}(0.983868,0.904867,0.136897), RGB{Float64}(0.993248,0.906157,0.143936)], "matplotlib", "perceptually uniform sequential")

# %%
ColorSchemes.gray
# Out:
# ColorScheme(ColorTypes.RGB{Float64}[RGB{Float64}(5.119113838889112e-7,2.0522701956616554e-6,5.982577941045683e-6), RGB{Float64}(0.0002598440803609316,0.00026259440245361075,0.00027706228396051196), RGB{Float64}(0.0008656156394278344,0.0008570638031131799,0.0008794207369001088), RGB{Float64}(0.001769403238430108,0.0017403680581581408,0.0017686070963996048), RGB{Float64}(0.002949472160671299,0.002891903379202927,0.002924180394823832), RGB{Float64}(0.004392323531342204,0.004298904740810658,0.004333431047933434), RGB{Float64}(0.00608855311595789,0.005952519318106651,0.005987527380406318), RGB{Float64}(0.008031191715623246,0.00784622292261931,0.00787995029696465), RGB{Float64}(0.010214875235272093,0.00997502608955014,0.010005706087016208), RGB{Float64}(0.012635372261218893,0.012335021633001353,0.012360877171488911)  …  RGB{Float64}(0.9522264455488126,0.9514367761124457,0.9463010502097274), RGB{Float64}(0.957392404604907,0.9566123153508007,0.9514455668469503), RGB{Float64}(0.9625784090357906,0.9618078382604079,0.9566099573635957), RGB{Float64}(0.9677846288648154,0.9670235129241013,0.9617943891606574), RGB{Float64}(0.973011235703915,0.972259508998241,0.9669990312055218), RGB{Float64}(0.978258402776717,0.9775159977355695,0.972224054054729), RGB{Float64}(0.983526304942001,0.982793152008386,0.9774696298770532), RGB{Float64}(0.9888151187175039,0.9880911463320615,0.9827359324769277), RGB{Float64}(0.9941250223040635,0.9934101568888957,0.9880231373182063), RGB{Float64}(0.9994561956101177,0.9987503615523224,0.9933314215482737)], "cmocean", "")

# %%
ColorSchemes.matter
# Out:
# ColorScheme(ColorTypes.RGB{Float64}[RGB{Float64}(0.9942936149611202,0.930327795323208,0.6910969022498408), RGB{Float64}(0.9938034737629607,0.9248067799917484,0.6856470896792072), RGB{Float64}(0.9932915386396505,0.919299374769053,0.6802308895677182), RGB{Float64}(0.9927922245331627,0.9137917294903226,0.6748329403835298), RGB{Float64}(0.9922937701498861,0.9082882194233707,0.6694590190525576), RGB{Float64}(0.9917843550306121,0.9027933977435593,0.6641148019075449), RGB{Float64}(0.9912962746539998,0.8972938428980344,0.6587860434151367), RGB{Float64}(0.9907825925330568,0.8918085346471608,0.6534941055176842), RGB{Float64}(0.9902949549053172,0.8863158938146131,0.6482161486636766), RGB{Float64}(0.9897868190815676,0.8808350065840213,0.6429731121246739)  …  RGB{Float64}(0.22974485429112435,0.07090635374932228,0.2734830227534651), RGB{Float64}(0.22474604355451955,0.0697343048702469,0.2701981884636781), RGB{Float64}(0.21976179144933672,0.0685259925198044,0.26688758887278374), RGB{Float64}(0.21478768714283408,0.06728630515821912,0.263551482229945), RGB{Float64}(0.2098235281541685,0.06601485651366462,0.26019055850201595), RGB{Float64}(0.2048690954628697,0.0647112448057679,0.25680549144898185), RGB{Float64}(0.19993023373401114,0.06336777961956377,0.25339802823103286), RGB{Float64}(0.19500160024612118,0.061990205931648286,0.24996804552033358), RGB{Float64}(0.1900821894571196,0.06057894133574073,0.2465160535125), RGB{Float64}(0.18517171283533682,0.05913348735199072,0.2430426744218359)], "cmocean", "yellow through orange and purple to black")

# %%
viridis12 = ColorScheme(ColorSchemes.viridis.colors[1:23:end])
# Out:
# ColorScheme(ColorTypes.RGB{Float64}[RGB{Float64}(0.267004,0.004874,0.329415), RGB{Float64}(0.283072,0.130895,0.449241), RGB{Float64}(0.262138,0.242286,0.520837), RGB{Float64}(0.220057,0.343307,0.549413), RGB{Float64}(0.179019,0.433756,0.55743), RGB{Float64}(0.144759,0.519093,0.556572), RGB{Float64}(0.119738,0.603785,0.5414), RGB{Float64}(0.162016,0.687316,0.499129), RGB{Float64}(0.304148,0.764704,0.419943), RGB{Float64}(0.506271,0.828786,0.300362), RGB{Float64}(0.741388,0.873449,0.149561), RGB{Float64}(0.974417,0.90359,0.130215)], "general", "")

# %%
Parula.parula
# Out:
# ColorScheme(ColorTypes.RGB{Float64}[RGB{Float64}(0.2422,0.1504,0.6603), RGB{Float64}(0.2504,0.165,0.7076), RGB{Float64}(0.2578,0.1818,0.7511), RGB{Float64}(0.2647,0.1978,0.7952), RGB{Float64}(0.2706,0.2147,0.8364), RGB{Float64}(0.2751,0.2342,0.871), RGB{Float64}(0.2783,0.2559,0.8991), RGB{Float64}(0.2803,0.2782,0.9221), RGB{Float64}(0.2813,0.3006,0.9414), RGB{Float64}(0.281,0.3228,0.9579)  …  RGB{Float64}(0.997,0.7659,0.2199), RGB{Float64}(0.9952,0.7893,0.2028), RGB{Float64}(0.9892,0.8136,0.1885), RGB{Float64}(0.9786,0.8386,0.1766), RGB{Float64}(0.9676,0.8639,0.1643), RGB{Float64}(0.961,0.889,0.1537), RGB{Float64}(0.9597,0.9135,0.1423), RGB{Float64}(0.9628,0.9373,0.1265), RGB{Float64}(0.9691,0.9606,0.1064), RGB{Float64}(0.9769,0.9839,0.0805)], "Parula", "From MATLAB")

# %%
EchogramColorSchemes.DT4
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(0.0,0.0,0.0), RGB{N0f8}(0.239,0.094,0.192), RGB{N0f8}(0.251,0.0,0.502), RGB{N0f8}(0.125,0.0,0.753), RGB{N0f8}(0.0,0.0,1.0), RGB{N0f8}(0.0,0.502,1.0), RGB{N0f8}(0.082,0.918,0.918), RGB{N0f8}(0.055,0.945,0.612), RGB{N0f8}(0.027,0.973,0.306), RGB{N0f8}(0.0,1.0,0.0), RGB{N0f8}(0.333,1.0,0.0), RGB{N0f8}(0.667,1.0,0.0), RGB{N0f8}(1.0,1.0,0.0), RGB{N0f8}(1.0,0.749,0.0), RGB{N0f8}(1.0,0.502,0.0), RGB{N0f8}(1.0,0.0,0.0)], "DT4", "This color scheme has been developed for viewing data recorded from BioSonics echosounders.")

# %%
EchogramColorSchemes.EK500
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(0.624,0.624,0.624), RGB{N0f8}(0.373,0.373,0.373), RGB{N0f8}(0.0,0.0,1.0), RGB{N0f8}(0.0,0.0,0.498), RGB{N0f8}(0.0,0.749,0.0), RGB{N0f8}(0.0,0.498,0.0), RGB{N0f8}(1.0,1.0,0.0), RGB{N0f8}(1.0,0.498,0.0), RGB{N0f8}(1.0,0.0,0.749), RGB{N0f8}(1.0,0.0,0.0), RGB{N0f8}(0.651,0.325,0.235), RGB{N0f8}(0.471,0.235,0.157)], "EK500", "This color scheme has been developed for viewing data recorded from Simrad Ex500, Ex60, Ex70 and ME70 echosounders.")

# %%
EchogramColorSchemes.EK80
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(0.612,0.541,0.659), RGB{N0f8}(0.553,0.49,0.588), RGB{N0f8}(0.494,0.443,0.518), RGB{N0f8}(0.439,0.392,0.447), RGB{N0f8}(0.38,0.345,0.376), RGB{N0f8}(0.322,0.298,0.306), RGB{N0f8}(0.267,0.298,0.369), RGB{N0f8}(0.208,0.325,0.506), RGB{N0f8}(0.153,0.353,0.639), RGB{N0f8}(0.094,0.376,0.773)  …  RGB{N0f8}(0.69,0.224,0.192), RGB{N0f8}(0.667,0.212,0.2), RGB{N0f8}(0.647,0.2,0.212), RGB{N0f8}(0.624,0.184,0.22), RGB{N0f8}(0.6,0.173,0.227), RGB{N0f8}(0.588,0.153,0.22), RGB{N0f8}(0.592,0.122,0.176), RGB{N0f8}(0.6,0.09,0.129), RGB{N0f8}(0.604,0.059,0.086), RGB{N0f8}(0.608,0.027,0.043)], "EK80", "This color scheme has been developed for viewing data recorded from Simrad EK80 echo sounders.")

# %%
EchogramColorSchemes.FurunoFQ80
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(0.169,0.494,0.502), RGB{N0f8}(0.0,0.0,1.0), RGB{N0f8}(0.498,0.988,0.996), RGB{N0f8}(0.0,0.502,0.439), RGB{N0f8}(0.0,0.627,0.0), RGB{N0f8}(0.0,1.0,0.0), RGB{N0f8}(0.922,0.996,0.0), RGB{N0f8}(0.996,0.749,0.498), RGB{N0f8}(0.996,0.502,0.004), RGB{N0f8}(1.0,0.0,0.0), RGB{N0f8}(0.576,0.0,0.0)], "Furuno FQ80", "This color scheme has been developed for viewing data recorded from Furuno FQ80 echosounders. ")

# %%
EchogramColorSchemes.HTI
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(0.0,0.0,1.0), RGB{N0f8}(0.0,0.125,1.0), RGB{N0f8}(0.0,0.251,1.0), RGB{N0f8}(0.0,0.376,1.0), RGB{N0f8}(0.0,0.502,1.0), RGB{N0f8}(0.0,0.624,1.0), RGB{N0f8}(0.0,0.749,1.0), RGB{N0f8}(0.0,0.875,1.0), RGB{N0f8}(0.0,1.0,1.0), RGB{N0f8}(0.165,1.0,0.827)  …  RGB{N0f8}(1.0,0.573,0.0), RGB{N0f8}(1.0,0.427,0.0), RGB{N0f8}(1.0,0.286,0.0), RGB{N0f8}(1.0,0.141,0.0), RGB{N0f8}(1.0,0.0,0.0), RGB{N0f8}(1.0,0.0,0.251), RGB{N0f8}(1.0,0.0,0.502), RGB{N0f8}(1.0,0.0,0.749), RGB{N0f8}(1.0,0.0,1.0), RGB{N0f8}(1.0,0.502,1.0)], "HTI", "These color schemes have been developed for viewing data recorded from HTI echosounders")

# %%
EchogramColorSchemes.Kaijo
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(0.627,0.878,0.753), RGB{N0f8}(0.506,0.757,0.878), RGB{N0f8}(0.0,0.506,0.875), RGB{N0f8}(0.251,0.502,0.502), RGB{N0f8}(0.0,0.875,0.506), RGB{N0f8}(0.0,0.875,0.0), RGB{N0f8}(0.0,0.624,0.0), RGB{N0f8}(0.0,0.376,0.0), RGB{N0f8}(0.502,0.502,0.251), RGB{N0f8}(0.549,0.549,0.451), RGB{N0f8}(1.0,0.502,0.0), RGB{N0f8}(1.0,0.502,0.502), RGB{N0f8}(1.0,0.0,0.0), RGB{N0f8}(0.502,0.0,0.0), RGB{N0f8}(0.251,0.0,0.0)], "Kaijo", "This color scheme has been developed for viewing data recorded from Kaijo echosounders.")

# %%
EchogramColorSchemes.LSSS
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(1.0,0.902,1.0), RGB{N0f8}(0.98,0.875,0.992), RGB{N0f8}(0.957,0.847,0.98), RGB{N0f8}(0.929,0.824,0.973), RGB{N0f8}(0.898,0.8,0.961), RGB{N0f8}(0.867,0.773,0.953), RGB{N0f8}(0.831,0.749,0.941), RGB{N0f8}(0.792,0.725,0.933), RGB{N0f8}(0.753,0.702,0.922), RGB{N0f8}(0.71,0.678,0.914)  …  RGB{N0f8}(0.596,0.576,0.102), RGB{N0f8}(0.588,0.522,0.09), RGB{N0f8}(0.576,0.463,0.078), RGB{N0f8}(0.569,0.404,0.071), RGB{N0f8}(0.557,0.345,0.059), RGB{N0f8}(0.549,0.286,0.047), RGB{N0f8}(0.537,0.231,0.039), RGB{N0f8}(0.529,0.173,0.027), RGB{N0f8}(0.518,0.114,0.02), RGB{N0f8}(0.51,0.059,0.008)], "LSSS", "This color scheme is used in the Large Scale Survey System, LSSS.")

# %%
EchogramColorSchemes.Sonic
# Out:
# ColorScheme(ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}[RGB{N0f8}(0.0,0.0,0.376), RGB{N0f8}(0.0,0.0,0.416), RGB{N0f8}(0.0,0.0,0.455), RGB{N0f8}(0.0,0.0,0.494), RGB{N0f8}(0.0,0.0,0.529), RGB{N0f8}(0.0,0.0,0.569), RGB{N0f8}(0.0,0.0,0.608), RGB{N0f8}(0.0,0.0,0.647), RGB{N0f8}(0.0,0.0,0.686), RGB{N0f8}(0.0,0.0,0.725)  …  RGB{N0f8}(0.745,0.0,0.0), RGB{N0f8}(0.718,0.0,0.0), RGB{N0f8}(0.69,0.0,0.0), RGB{N0f8}(0.663,0.0,0.0), RGB{N0f8}(0.635,0.0,0.0), RGB{N0f8}(0.608,0.0,0.0), RGB{N0f8}(0.584,0.0,0.0), RGB{N0f8}(0.557,0.0,0.0), RGB{N0f8}(0.529,0.0,0.0), RGB{N0f8}(0.502,0.0,0.0)], "Sonic", "These color schemes have been developed for viewing data recorded from Sonic KFC-6000/KSE-300 echosounders.")

# %%
heated_body = [HSV(i * 60, 1.0, i) for i in range(0,stop=1,length=100)]
# Out:
# 100-element Array{HSV{Float64},1} with eltype HSV{Float64}:
#  HSV{Float64}(0.0,1.0,0.0)
#  HSV{Float64}(0.6060606060606061,1.0,0.010101010101010102)
#  HSV{Float64}(1.2121212121212122,1.0,0.020202020202020204)
#  HSV{Float64}(1.8181818181818183,1.0,0.030303030303030304)
#  HSV{Float64}(2.4242424242424243,1.0,0.04040404040404041)
#  HSV{Float64}(3.0303030303030303,1.0,0.050505050505050504)
#  HSV{Float64}(3.6363636363636367,1.0,0.06060606060606061)
#  HSV{Float64}(4.242424242424242,1.0,0.0707070707070707)
#  HSV{Float64}(4.848484848484849,1.0,0.08080808080808081)
#  HSV{Float64}(5.454545454545455,1.0,0.09090909090909091)
#  HSV{Float64}(6.0606060606060606,1.0,0.10101010101010101)
#  HSV{Float64}(6.666666666666666,1.0,0.1111111111111111)
#  HSV{Float64}(7.272727272727273,1.0,0.12121212121212122)
#  ⋮
#  HSV{Float64}(53.33333333333333,1.0,0.8888888888888888)
#  HSV{Float64}(53.93939393939394,1.0,0.898989898989899)
#  HSV{Float64}(54.54545454545455,1.0,0.9090909090909091)
#  HSV{Float64}(55.151515151515156,1.0,0.9191919191919192)
#  HSV{Float64}(55.75757575757576,1.0,0.9292929292929293)
#  HSV{Float64}(56.36363636363637,1.0,0.9393939393939394)
#  HSV{Float64}(56.96969696969697,1.0,0.9494949494949495)
#  HSV{Float64}(57.57575757575757,1.0,0.9595959595959596)
#  HSV{Float64}(58.18181818181819,1.0,0.9696969696969697)
#  HSV{Float64}(58.78787878787879,1.0,0.9797979797979798)
#  HSV{Float64}(59.3939393939394,1.0,0.98989898989899)
#  HSV{Float64}(60.0,1.0,1.0)

# %%
hsv_grayscale = [HSV(0, 0, v) for v in range(0,stop=1,length=100)]
# Out:
# 100-element Array{HSV{Float64},1} with eltype HSV{Float64}:
#  HSV{Float64}(0.0,0.0,0.0)
#  HSV{Float64}(0.0,0.0,0.010101010101010102)
#  HSV{Float64}(0.0,0.0,0.020202020202020204)
#  HSV{Float64}(0.0,0.0,0.030303030303030304)
#  HSV{Float64}(0.0,0.0,0.04040404040404041)
#  HSV{Float64}(0.0,0.0,0.050505050505050504)
#  HSV{Float64}(0.0,0.0,0.06060606060606061)
#  HSV{Float64}(0.0,0.0,0.0707070707070707)
#  HSV{Float64}(0.0,0.0,0.08080808080808081)
#  HSV{Float64}(0.0,0.0,0.09090909090909091)
#  HSV{Float64}(0.0,0.0,0.10101010101010101)
#  HSV{Float64}(0.0,0.0,0.1111111111111111)
#  HSV{Float64}(0.0,0.0,0.12121212121212122)
#  ⋮
#  HSV{Float64}(0.0,0.0,0.8888888888888888)
#  HSV{Float64}(0.0,0.0,0.898989898989899)
#  HSV{Float64}(0.0,0.0,0.9090909090909091)
#  HSV{Float64}(0.0,0.0,0.9191919191919192)
#  HSV{Float64}(0.0,0.0,0.9292929292929293)
#  HSV{Float64}(0.0,0.0,0.9393939393939394)
#  HSV{Float64}(0.0,0.0,0.9494949494949495)
#  HSV{Float64}(0.0,0.0,0.9595959595959596)
#  HSV{Float64}(0.0,0.0,0.9696969696969697)
#  HSV{Float64}(0.0,0.0,0.9797979797979798)
#  HSV{Float64}(0.0,0.0,0.98989898989899)
#  HSV{Float64}(0.0,0.0,1.0)

# %%
hsv_increasing_saturation = [HSV(300, s, 1.0) for s in range(0,stop=1,length=100)]
# Out:
# 100-element Array{HSV{Float64},1} with eltype HSV{Float64}:
#  HSV{Float64}(300.0,0.0,1.0)
#  HSV{Float64}(300.0,0.010101010101010102,1.0)
#  HSV{Float64}(300.0,0.020202020202020204,1.0)
#  HSV{Float64}(300.0,0.030303030303030304,1.0)
#  HSV{Float64}(300.0,0.04040404040404041,1.0)
#  HSV{Float64}(300.0,0.050505050505050504,1.0)
#  HSV{Float64}(300.0,0.06060606060606061,1.0)
#  HSV{Float64}(300.0,0.0707070707070707,1.0)
#  HSV{Float64}(300.0,0.08080808080808081,1.0)
#  HSV{Float64}(300.0,0.09090909090909091,1.0)
#  HSV{Float64}(300.0,0.10101010101010101,1.0)
#  HSV{Float64}(300.0,0.1111111111111111,1.0)
#  HSV{Float64}(300.0,0.12121212121212122,1.0)
#  ⋮
#  HSV{Float64}(300.0,0.8888888888888888,1.0)
#  HSV{Float64}(300.0,0.898989898989899,1.0)
#  HSV{Float64}(300.0,0.9090909090909091,1.0)
#  HSV{Float64}(300.0,0.9191919191919192,1.0)
#  HSV{Float64}(300.0,0.9292929292929293,1.0)
#  HSV{Float64}(300.0,0.9393939393939394,1.0)
#  HSV{Float64}(300.0,0.9494949494949495,1.0)
#  HSV{Float64}(300.0,0.9595959595959596,1.0)
#  HSV{Float64}(300.0,0.9696969696969697,1.0)
#  HSV{Float64}(300.0,0.9797979797979798,1.0)
#  HSV{Float64}(300.0,0.98989898989899,1.0)
#  HSV{Float64}(300.0,1.0,1.0)

# %%
hsv_decreasing_saturation = reverse(hsv_increasing_saturation)
# Out:
# 100-element Array{HSV{Float64},1} with eltype HSV{Float64}:
#  HSV{Float64}(300.0,1.0,1.0)
#  HSV{Float64}(300.0,0.98989898989899,1.0)
#  HSV{Float64}(300.0,0.9797979797979798,1.0)
#  HSV{Float64}(300.0,0.9696969696969697,1.0)
#  HSV{Float64}(300.0,0.9595959595959596,1.0)
#  HSV{Float64}(300.0,0.9494949494949495,1.0)
#  HSV{Float64}(300.0,0.9393939393939394,1.0)
#  HSV{Float64}(300.0,0.9292929292929293,1.0)
#  HSV{Float64}(300.0,0.9191919191919192,1.0)
#  HSV{Float64}(300.0,0.9090909090909091,1.0)
#  HSV{Float64}(300.0,0.898989898989899,1.0)
#  HSV{Float64}(300.0,0.8888888888888888,1.0)
#  HSV{Float64}(300.0,0.8787878787878788,1.0)
#  ⋮
#  HSV{Float64}(300.0,0.1111111111111111,1.0)
#  HSV{Float64}(300.0,0.10101010101010101,1.0)
#  HSV{Float64}(300.0,0.09090909090909091,1.0)
#  HSV{Float64}(300.0,0.08080808080808081,1.0)
#  HSV{Float64}(300.0,0.0707070707070707,1.0)
#  HSV{Float64}(300.0,0.06060606060606061,1.0)
#  HSV{Float64}(300.0,0.050505050505050504,1.0)
#  HSV{Float64}(300.0,0.04040404040404041,1.0)
#  HSV{Float64}(300.0,0.030303030303030304,1.0)
#  HSV{Float64}(300.0,0.020202020202020204,1.0)
#  HSV{Float64}(300.0,0.010101010101010102,1.0)
#  HSV{Float64}(300.0,0.0,1.0)

# %%
lab_grayscale = [Lab(l,0,0) for l in range(0,stop=100,length=100)]
# Out:
# 100-element Array{Lab{Float64},1} with eltype Lab{Float64}:
#  Lab{Float64}(0.0,0.0,0.0)
#  Lab{Float64}(1.0101010101010102,0.0,0.0)
#  Lab{Float64}(2.0202020202020203,0.0,0.0)
#  Lab{Float64}(3.0303030303030303,0.0,0.0)
#  Lab{Float64}(4.040404040404041,0.0,0.0)
#  Lab{Float64}(5.05050505050505,0.0,0.0)
#  Lab{Float64}(6.0606060606060606,0.0,0.0)
#  Lab{Float64}(7.070707070707071,0.0,0.0)
#  Lab{Float64}(8.080808080808081,0.0,0.0)
#  Lab{Float64}(9.090909090909092,0.0,0.0)
#  Lab{Float64}(10.1010101010101,0.0,0.0)
#  Lab{Float64}(11.11111111111111,0.0,0.0)
#  Lab{Float64}(12.121212121212121,0.0,0.0)
#  ⋮
#  Lab{Float64}(88.88888888888889,0.0,0.0)
#  Lab{Float64}(89.8989898989899,0.0,0.0)
#  Lab{Float64}(90.9090909090909,0.0,0.0)
#  Lab{Float64}(91.91919191919192,0.0,0.0)
#  Lab{Float64}(92.92929292929293,0.0,0.0)
#  Lab{Float64}(93.93939393939394,0.0,0.0)
#  Lab{Float64}(94.94949494949495,0.0,0.0)
#  Lab{Float64}(95.95959595959596,0.0,0.0)
#  Lab{Float64}(96.96969696969697,0.0,0.0)
#  Lab{Float64}(97.97979797979798,0.0,0.0)
#  Lab{Float64}(98.98989898989899,0.0,0.0)
#  Lab{Float64}(100.0,0.0,0.0)

# %%
rainbow = [HSV(i * 240, 1.0, 1.0) for i in range(0,stop=1,length=100)]
# Out:
# 100-element Array{HSV{Float64},1} with eltype HSV{Float64}:
#  HSV{Float64}(0.0,1.0,1.0)
#  HSV{Float64}(2.4242424242424243,1.0,1.0)
#  HSV{Float64}(4.848484848484849,1.0,1.0)
#  HSV{Float64}(7.272727272727273,1.0,1.0)
#  HSV{Float64}(9.696969696969697,1.0,1.0)
#  HSV{Float64}(12.121212121212121,1.0,1.0)
#  HSV{Float64}(14.545454545454547,1.0,1.0)
#  HSV{Float64}(16.96969696969697,1.0,1.0)
#  HSV{Float64}(19.393939393939394,1.0,1.0)
#  HSV{Float64}(21.81818181818182,1.0,1.0)
#  HSV{Float64}(24.242424242424242,1.0,1.0)
#  HSV{Float64}(26.666666666666664,1.0,1.0)
#  HSV{Float64}(29.090909090909093,1.0,1.0)
#  ⋮
#  HSV{Float64}(213.33333333333331,1.0,1.0)
#  HSV{Float64}(215.75757575757575,1.0,1.0)
#  HSV{Float64}(218.1818181818182,1.0,1.0)
#  HSV{Float64}(220.60606060606062,1.0,1.0)
#  HSV{Float64}(223.03030303030303,1.0,1.0)
#  HSV{Float64}(225.45454545454547,1.0,1.0)
#  HSV{Float64}(227.87878787878788,1.0,1.0)
#  HSV{Float64}(230.30303030303028,1.0,1.0)
#  HSV{Float64}(232.72727272727275,1.0,1.0)
#  HSV{Float64}(235.15151515151516,1.0,1.0)
#  HSV{Float64}(237.5757575757576,1.0,1.0)
#  HSV{Float64}(240.0,1.0,1.0)

# %%
using Interpolations

function interp1(X, V, Xq)
    knots = (X,)
    itp = interpolate(knots, V, Gridded(Linear()))
    itp[Xq]
end

linspace(x,y,z) = range(x, stop=y,length=z)
# Out:
# linspace (generic function with 1 method)

# %%
# Load the colours from the digitised colour map
x = unique(Images.load("data/raw/isoluminant-rainbow-sample.png")[1,:])

# Convert to CIELab
x = map( x -> Lab(RGB(x.r, x.g, x.b)), x)

# Find the mean lightness and use it to ensure isoluminance
m = mean([x.l for x in x])
x = map(x -> Lab(m, x.a, x.b), x)

# Interpolate to get 100 colours
idx1 = linspace(1,100, length(x))
idx2 = collect(1:100)
x = [[x.l x.a x.b] for x in x]
x = interp1(idx1, x, idx2)
isoluminant_rainbow = [Lab(x[1],x[2],x[3]) for x in x]
# Out:
# 100-element Array{Lab{Float64},1} with eltype Lab{Float64}:
#  Lab{Float64}(65.14354705810547,9.707213401794434,-20.69729232788086)
#  Lab{Float64}(65.14354705810547,8.607107663395428,-21.113639060897057)
#  Lab{Float64}(65.14354705810547,7.912569498774982,-21.383243772718643)
#  Lab{Float64}(65.14354705810547,7.106591773755623,-21.434438474250562)
#  Lab{Float64}(65.14354705810547,6.752151031686802,-21.94740971651944)
#  Lab{Float64}(65.14354705810547,6.706736906610354,-23.047877610331835)
#  Lab{Float64}(65.14354705810547,5.8831119103865195,-23.34137604453347)
#  Lab{Float64}(65.14354705810547,4.353589712971389,-22.886512621484624)
#  Lab{Float64}(65.14354705810547,2.794262108176646,-22.346885218764797)
#  Lab{Float64}(65.14354705810547,1.9546236124905674,-22.325720873746004)
#  Lab{Float64}(65.14354705810547,1.4161391968678945,-22.571551351836234)
#  Lab{Float64}(65.14354705810547,0.09757246408197698,-23.044924630059135)
#  Lab{Float64}(65.14354705810547,-0.8472947713100554,-23.268767327973336)
#  ⋮
#  Lab{Float64}(65.14354705810547,15.557158682081436,18.83680703904893)
#  Lab{Float64}(65.14354705810547,15.781036376953125,17.877792454729178)
#  Lab{Float64}(65.14354705810547,16.71482762423428,17.222509037364617)
#  Lab{Float64}(65.14354705810547,16.904030135183625,16.81919034322103)
#  Lab{Float64}(65.14354705810547,17.13342996077104,15.860274555707218)
#  Lab{Float64}(65.14354705810547,17.916846535422586,14.561331720063182)
#  Lab{Float64}(65.14354705810547,18.52860419918793,13.76212954280352)
#  Lab{Float64}(65.14354705810547,19.46328737278177,13.247929553792934)
#  Lab{Float64}(65.14354705810547,20.91211648420854,11.520142063950049)
#  Lab{Float64}(65.14354705810547,22.19546907598322,9.626523913759174)
#  Lab{Float64}(65.14354705810547,22.07277375038224,8.722582470286971)
#  Lab{Float64}(65.14354705810547,22.703786849975586,7.936864852905273)

# %%
x = unique(load("data/raw/lab-isoluminant-saturation-sample.png")[1,:])
x = map( x -> Lab(RGB(x.r, x.g, x.b)), x)
m = mean([x.l for x in x])
x = map(x -> Lab(m, x.a, x.b), x)
idx1 = linspace(1,100, length(x))
idx2 = collect(1:100)
x = [[x.l x.a x.b] for x in x]
x = interp1(idx1, x, idx2)
isoluminant_sat = [Lab(x[1],x[2],x[3]) for x in x]
# Out:
# 100-element Array{Lab{Float64},1} with eltype Lab{Float64}:
#  Lab{Float64}(54.812889099121094,-2.976142644882202,0.18164265155792236)
#  Lab{Float64}(54.812889099121094,-2.586974830338449,0.2895458695864437)
#  Lab{Float64}(54.812889099121094,-2.0120160483350658,-0.0946620059284297)
#  Lab{Float64}(54.812889099121094,-1.5613742994539666,-0.01260800287127493)
#  Lab{Float64}(54.812889099121094,-0.7081330472772772,-0.3464160119042252)
#  Lab{Float64}(54.81288909912109,-0.5052519302175502,-0.6613453590508663)
#  Lab{Float64}(54.812889099121094,-0.28054411837850546,-0.09861749779255743)
#  Lab{Float64}(54.812889099121094,0.2171396104540965,-0.26692401427011303)
#  Lab{Float64}(54.812889099121094,0.7674354639920321,-0.943372292350037)
#  Lab{Float64}(54.812889099121094,1.1079002347859466,-1.0410466681827197)
#  Lab{Float64}(54.812889099121094,1.8547192077444055,-1.1593475197300767)
#  Lab{Float64}(54.812889099121094,1.9897473388248021,-0.8414554595947268)
#  Lab{Float64}(54.812889099121094,2.0633630246827095,-0.47840234005089965)
#  ⋮
#  Lab{Float64}(54.812889099121094,37.96002960205078,6.061046971215142)
#  Lab{Float64}(54.812889099121094,38.21391978408351,6.684380834752869)
#  Lab{Float64}(54.812889099121094,38.681502602317124,7.083379051902077)
#  Lab{Float64}(54.812889099121094,39.4329728791208,6.483640685225978)
#  Lab{Float64}(54.812889099121094,39.099891624065364,7.2141475870151694)
#  Lab{Float64}(54.812889099121094,39.55450439453125,7.556854854930531)
#  Lab{Float64}(54.812889099121094,40.056048499213325,7.7166142704510925)
#  Lab{Float64}(54.812889099121094,40.55950746632585,7.520908596539741)
#  Lab{Float64}(54.812889099121094,41.9508575670647,6.685519362940929)
#  Lab{Float64}(54.812889099121094,42.09579722086588,6.533756651059545)
#  Lab{Float64}(54.812889099121094,42.469793300435995,6.7923935928730055)
#  Lab{Float64}(54.812889099121094,42.839351654052734,7.030668258666992)
