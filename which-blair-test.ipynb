# %% [markdown]
# # The Which Blair Test
#
# ## Introduction
#
# The “Which Blair Project” provides a quick visual test for evaluating colour maps
# (Rogowitz & Kalvin 2001). In psychophysical testing, the perceptual quality of colour
# maps was assessed by using them to render a photograph of a human face. A strong
# correlation was found between the perceived naturalness of images, luminance monotonicity
# and the suitability of colour maps for rendering continuous scalar data.

# %% [markdown]
# ## Method

# %%
using Images
using ColorSchemes

# %% [markdown]
# The image of Tony Blair, adapted for our experiments, is courtesy of the World Affairs
# Council and is licensed under the terms of the Creative Commons Attribution 2.0 Generic
# license. (We don't have the image from the original paper).

# %%
img = load("data/processed/blair/blair.png");

# %%
imresize(img,ratio=0.2)
# Out:
# 144×99 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.09)   …  Gray{N0f8}(0.059)
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.09)      Gray{N0f8}(0.051)
#  Gray{N0f8}(0.086)  Gray{N0f8}(0.086)     Gray{N0f8}(0.078)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.094)     Gray{N0f8}(0.078)
#  Gray{N0f8}(0.086)  Gray{N0f8}(0.09)      Gray{N0f8}(0.063)
#  Gray{N0f8}(0.086)  Gray{N0f8}(0.09)   …  Gray{N0f8}(0.059)
#  Gray{N0f8}(0.086)  Gray{N0f8}(0.094)     Gray{N0f8}(0.059)
#  Gray{N0f8}(0.09)   Gray{N0f8}(0.094)     Gray{N0f8}(0.071)
#  Gray{N0f8}(0.094)  Gray{N0f8}(0.102)     Gray{N0f8}(0.051)
#  Gray{N0f8}(0.09)   Gray{N0f8}(0.09)      Gray{N0f8}(0.055)
#  Gray{N0f8}(0.102)  Gray{N0f8}(0.098)  …  Gray{N0f8}(0.059)
#  Gray{N0f8}(0.098)  Gray{N0f8}(0.09)      Gray{N0f8}(0.063)
#  Gray{N0f8}(0.09)   Gray{N0f8}(0.086)     Gray{N0f8}(0.055)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.216)  Gray{N0f8}(0.22)      Gray{N0f8}(0.129)
#  Gray{N0f8}(0.208)  Gray{N0f8}(0.235)     Gray{N0f8}(0.224)
#  Gray{N0f8}(0.208)  Gray{N0f8}(0.224)     Gray{N0f8}(0.204)
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.227)  …  Gray{N0f8}(0.227)
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.243)     Gray{N0f8}(0.216)
#  Gray{N0f8}(0.208)  Gray{N0f8}(0.231)     Gray{N0f8}(0.239)
#  Gray{N0f8}(0.239)  Gray{N0f8}(0.227)     Gray{N0f8}(0.247)
#  Gray{N0f8}(0.22)   Gray{N0f8}(0.208)     Gray{N0f8}(0.235)
#  Gray{N0f8}(0.231)  Gray{N0f8}(0.231)  …  Gray{N0f8}(0.243)
#  Gray{N0f8}(0.239)  Gray{N0f8}(0.227)     Gray{N0f8}(0.224)
#  Gray{N0f8}(0.208)  Gray{N0f8}(0.196)     Gray{N0f8}(0.243)
#  Gray{N0f8}(0.212)  Gray{N0f8}(0.196)     Gray{N0f8}(0.216)

# %%
function which_blair_test(colorscheme::ColorScheme)
    k = length(colorscheme.colors)
    map(x -> colorscheme.colors[trunc(Int,x.val * (k-1))+1], img)
end
# Out:
# which_blair_test (generic function with 1 method)

# %% [markdown]
# ## Results

# %%
imresize(which_blair_test(ColorSchemes.rainbow), ratio=0.2) # NB Not the same Rainbow used by Rogowitz & Kalvin
# Out:
# 144×99 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(0.31106,0.11758,0.664469)   …  RGB{Float64}(0.471412,0.108766,0.527016)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.471412,0.108766,0.527016)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.314299,0.117402,0.661692)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.31106,0.11758,0.664469)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.314299,0.117402,0.661692)
#  RGB{Float64}(0.31106,0.11758,0.664469)   …  RGB{Float64}(0.46842,0.10893,0.529581)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.468173,0.108944,0.529793)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.311397,0.117561,0.66418)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.47103,0.108787,0.527344)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.470985,0.108789,0.527382)
#  RGB{Float64}(0.31106,0.11758,0.664469)   …  RGB{Float64}(0.47094,0.108792,0.527421)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.314299,0.117402,0.661692)
#  RGB{Float64}(0.31106,0.11758,0.664469)      RGB{Float64}(0.471412,0.108766,0.527016)
#  ⋮                                        ⋱
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.301424,0.134799,0.681189)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24408,0.361242,0.816084)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24408,0.361242,0.816084)
#  RGB{Float64}(0.24408,0.361242,0.816084)  …  RGB{Float64}(0.24408,0.361242,0.816084)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24408,0.361242,0.816084)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24408,0.361242,0.816084)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24573,0.370629,0.815069)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24408,0.361242,0.816084)
#  RGB{Float64}(0.24408,0.361242,0.816084)  …  RGB{Float64}(0.244525,0.363776,0.81581)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24408,0.361242,0.816084)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.244516,0.363723,0.815816)
#  RGB{Float64}(0.24408,0.361242,0.816084)     RGB{Float64}(0.24408,0.361242,0.816084)

# %%
imresize(which_blair_test(ColorSchemes.viridis), ratio=0.2)
# Out:
# 144×99 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(0.283197,0.115919,0.436323)  …  RGB{Float64}(0.281891,0.0893377,0.412107)
#  RGB{Float64}(0.283194,0.115987,0.43638)      RGB{Float64}(0.280862,0.0786696,0.402106)
#  RGB{Float64}(0.283187,0.125374,0.444547)     RGB{Float64}(0.283162,0.115046,0.435535)
#  RGB{Float64}(0.282899,0.135277,0.452882)     RGB{Float64}(0.283191,0.115472,0.435929)
#  RGB{Float64}(0.283188,0.12502,0.44424)       RGB{Float64}(0.282339,0.0951691,0.417527)
#  RGB{Float64}(0.283179,0.12602,0.445102)   …  RGB{Float64}(0.281896,0.0893646,0.412132)
#  RGB{Float64}(0.283187,0.125839,0.444952)     RGB{Float64}(0.281938,0.0898692,0.412603)
#  RGB{Float64}(0.283029,0.131725,0.44992)      RGB{Float64}(0.282871,0.104641,0.426214)
#  RGB{Float64}(0.282909,0.135249,0.452868)     RGB{Float64}(0.281026,0.0802862,0.403622)
#  RGB{Float64}(0.283048,0.131545,0.449782)     RGB{Float64}(0.281385,0.0837423,0.406871)
#  RGB{Float64}(0.282169,0.147258,0.462552)  …  RGB{Float64}(0.281926,0.089697,0.412444)
#  RGB{Float64}(0.282577,0.141589,0.458046)     RGB{Float64}(0.282319,0.0948482,0.417232)
#  RGB{Float64}(0.283039,0.131767,0.449968)     RGB{Float64}(0.281435,0.0842106,0.407311)
#  ⋮                                         ⋱
#  RGB{Float64}(0.246517,0.283946,0.536152)     RGB{Float64}(0.276896,0.181121,0.485835)
#  RGB{Float64}(0.250116,0.275061,0.533352)     RGB{Float64}(0.243373,0.291474,0.53834)
#  RGB{Float64}(0.250384,0.274392,0.533136)     RGB{Float64}(0.252184,0.269807,0.531587)
#  RGB{Float64}(0.244642,0.288445,0.537466)  …  RGB{Float64}(0.241228,0.296506,0.539714)
#  RGB{Float64}(0.244786,0.288116,0.537385)     RGB{Float64}(0.246656,0.283609,0.536051)
#  RGB{Float64}(0.249994,0.27534,0.533423)      RGB{Float64}(0.235321,0.309986,0.543048)
#  RGB{Float64}(0.235834,0.308824,0.54277)      RGB{Float64}(0.231453,0.318571,0.544902)
#  RGB{Float64}(0.244476,0.288832,0.537569)     RGB{Float64}(0.237529,0.305001,0.54187)
#  RGB{Float64}(0.239384,0.300767,0.540821)  …  RGB{Float64}(0.233724,0.313545,0.543835)
#  RGB{Float64}(0.235499,0.309586,0.542956)     RGB{Float64}(0.243011,0.29233,0.538581)
#  RGB{Float64}(0.250202,0.274837,0.533273)     RGB{Float64}(0.23353,0.31398,0.543933)
#  RGB{Float64}(0.248665,0.278686,0.534527)     RGB{Float64}(0.246735,0.283418,0.535994)

# %% [markdown]
# ## Discussion
#
# Subjective, but most people think the viridis image looks more natural than the rainbow image. We conclude that Viridis is better than Rainbow for rendering continuous scalar data.

# %% [markdown]
# ## References
#
# Rogowitz, B.E. & Kalvin, A.D., 2001. The Which Blair project: A quick visual method
# for evaluating perceptual color maps. In Proceedings of the conference on visualization’01.
# IEEE Computer Society, pp. 183–190.
